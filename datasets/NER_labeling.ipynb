# %% [markdown]
# ### Import the Libraries

# %%
import spacy
import os
from pathlib import Path

# %%
nlp = spacy.load("../models/model-best")

print("✅ Model loaded successufully !")
print(f"Entity types: {nlp.get_pipe('ner').labels}")
# Out:
# ✅ Model loaded successufully !
# ...
